# %% [markdown]
# <a href="https://colab.research.google.com/github/PhucThinh20146028/BTAIW7/blob/main/USA_housing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
url = '/content/USA_Housing.csv'
data = pd.read_csv(url)
data.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data.hist()
plt.show()

# %%
correlation = data.corr()
print(correlation)
# Out:
#                               Avg. Area Income  Avg. Area House Age  \
# Avg. Area Income                      1.000000            -0.002007
# Avg. Area House Age                  -0.002007             1.000000
# Avg. Area Number of Rooms            -0.011032            -0.009428
# Avg. Area Number of Bedrooms          0.019788             0.006149
# Area Population                      -0.016234            -0.018743
# Price                                 0.639734             0.452543
#
#                               Avg. Area Number of Rooms  \
# Avg. Area Income                              -0.011032
# Avg. Area House Age                           -0.009428
# Avg. Area Number of Rooms                      1.000000
# Avg. Area Number of Bedrooms                   0.462695
# Area Population                                0.002040
# Price                                          0.335664
#
#                               Avg. Area Number of Bedrooms  Area Population  \
# ...

# %%
sns.pairplot(data)

# %%
sns.heatmap(correlation,annot=True)
# Out:
# <Axes: >

# %%
data.plot(kind = 'scatter', x = 'Avg. Area Income', y = 'Price', figsize = (9,9), color = 'black')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='Avg. Area Income', ylabel='Price'>

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()

model.fit(X = pd.DataFrame(data['Avg. Area Income']), y = data['Price'])
print('Gia tri Intercept la: ', model.intercept_)
print('Gia tri Coeffient la: ', model.coef_)
model.score(X = pd.DataFrame(data['Avg. Area Income']), y = data['Price'])
# Out:
# Gia tri Intercept la:  -221579.4782059181
# Gia tri Coeffient la:  [21.19548317]
# 0.4092593070338846

# %%
data.plot(kind = 'scatter', x = 'Avg. Area Income', y = 'Price', figsize = (9,9), color = 'black')
y_pred = model.predict(X = pd.DataFrame(data['Avg. Area Income']))
plt.plot(data['Avg. Area Income'], y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['Avg. Area Income'],data['Avg. Area Income']**2]).T

y = data['Price']

model.fit(X,y = data['Price'])
print('He so Intercept la: ', model.intercept_)
print('He so Coeffient la: ', model.coef_)
print('Do chinh xac cua mo hinh la: ', model.score(X,y))
# Out:
# He so Intercept la:  5786.062805456808
# He so Coeffient la:  [1.43822894e+01 4.98015093e-05]
# Do chinh xac cua mo hinh la:  0.40978359512172113

# %%
range = np.arange(20000,110000,10)
X_range = pd.DataFrame([range, range**2]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'Avg. Area Income', y = 'Price', figsize = (9,9), color = 'black', xlim = (0.7))
plt.plot(range,y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['Avg. Area Income'],data['Avg. Area Income']**2,data['Avg. Area Income']**3]).T
y = data['Price']

model.fit(X,y = data['Price'])
print('He so Intercept la: ', model.intercept_)
print('He so Coeffient la: ', model.coef_)
print('Do chinh xac cua mo hinh la: ', model.score(X,y))

range = np.arange(20000,110000,10)
X_range = pd.DataFrame([range, range**2, range**3]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'Avg. Area Income', y = 'Price', figsize = (9,9), color = 'black', xlim = (0.7))
plt.plot(range,y_pred,color='blue')
# Out:
# He so Intercept la:  -90874.44992992934
# He so Coeffient la:  [ 1.88774722e+01 -1.79963602e-05  3.32345038e-10]
# Do chinh xac cua mo hinh la:  0.409792512563658
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['Avg. Area Income'],data['Avg. Area Income']**2,data['Avg. Area Income']**3,data['Avg. Area Income']**4]).T
y = data['Price']

model.fit(X,y = data['Price'])
print('He so Intercept la: ', model.intercept_)
print('He so Coeffient la: ', model.coef_)
print('Do chinh xac cua mo hinh la: ', model.score(X,y))

range = np.arange(20000,100000,10)
X_range = pd.DataFrame([range, range**2, range**3, range**4]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'Avg. Area Income', y = 'Price', figsize = (9,9), color = 'black',xlim=(0.7))
plt.plot(range,y_pred,color='blue')
# Out:
# He so Intercept la:  182027.255027388
# He so Coeffient la:  [ 1.04315844e-08  4.50868104e-04 -4.65376551e-09  1.92421491e-14]
# Do chinh xac cua mo hinh la:  0.40983861286665924
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['Avg. Area Income'],data['Avg. Area Income']**2,data['Avg. Area Income']**3,data['Avg. Area Income']**4,data['Avg. Area Income']**5]).T
y = data['Price']

model.fit(X,y = data['Price'])
print('He so Intercept la: ', model.intercept_)
print('He so Coeffient la: ', model.coef_)
print('Do chinh xac cua mo hinh la: ', model.score(X,y))

range = np.arange(20000,100000,10)
X_range = pd.DataFrame([range, range**2, range**3, range**4, range**5]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'Avg. Area Income', y = 'Price', figsize = (9,9), color = 'black',xlim=(0.7))
plt.plot(range,y_pred,color='blue')
# Out:
# He so Intercept la:  375116.49050026387
# He so Coeffient la:  [ 3.74179942e-18  6.64344187e-13  8.60779691e-09 -1.23704329e-13
#   5.36201215e-19]
# Do chinh xac cua mo hinh la:  0.40984578447873465
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['Avg. Area Income'],data['Avg. Area Income']**2,data['Avg. Area Income']**3,data['Avg. Area Income']**4,data['Avg. Area Income']**5,data['Avg. Area Income']**6]).T
y = data['Price']

model.fit(X,y = data['Price'])
print('He so Intercept la: ', model.intercept_)
print('He so Coeffient la: ', model.coef_)
print('Do chinh xac cua mo hinh la: ', model.score(X,y))

range = np.arange(20000,100000,10)
X_range = pd.DataFrame([range, range**2, range**3, range**4, range**5, range**6]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'Avg. Area Income', y = 'Price', figsize = (9,9), color = 'black',xlim=(0.7))
plt.plot(range,y_pred,color='blue')
# Out:
# He so Intercept la:  515270.9210667799
# He so Coeffient la:  [ 1.06215895e-27  5.35752178e-18  4.57563056e-18  1.45635072e-13
#  -2.40203437e-18  1.09261538e-23]
# Do chinh xac cua mo hinh la:  0.40961767558007456
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['Avg. Area Income'],data['Avg. Area Income']**2,data['Avg. Area Income']**3,data['Avg. Area Income']**4,data['Avg. Area Income']**5,data['Avg. Area Income']**6,data['Avg. Area Income']**7]).T
y = data['Price']

model.fit(X,y = data['Price'])
print('He so Intercept la: ', model.intercept_)
print('He so Coeffient la: ', model.coef_)
print('Do chinh xac cua mo hinh la: ', model.score(X,y))

range = np.arange(20000,100000,10)
X_range = pd.DataFrame([range, range**2, range**3, range**4, range**5, range**6,range**7]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'Avg. Area Income', y = 'Price', figsize = (9,9), color = 'black')
plt.plot(range,y_pred,color='blue')
# Out:
# He so Intercept la:  621949.3777805269
# He so Coeffient la:  [ 2.56154886e-37  9.86983663e-23  1.37078870e-27  7.35255649e-23
#   2.26722019e-18 -4.01434333e-23  1.88349176e-28]
# Do chinh xac cua mo hinh la:  0.4088326496358783
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()

model.fit(X = data.loc[:,['Avg. Area Income','Avg. Area House Age','Avg. Area Number of Rooms','Avg. Area Number of Bedrooms','Area Population']],y = data['Price'])
print('He so coeffient la: ',model.coef_)
print('He so intercept la: ',model.intercept_)
print('Do chinh xac cua mo hinh:',model.score(data.loc[:,['Avg. Area Income','Avg. Area House Age','Avg. Area Number of Rooms','Avg. Area Number of Bedrooms','Area Population']],y = data['Price']))
# Out:
# He so coeffient la:  [2.15780494e+01 1.65637027e+05 1.20659949e+05 1.65113905e+03
#  1.52007439e+01]
# He so intercept la:  -2637299.033328584
# Do chinh xac cua mo hinh: 0.9180238195089553
