# %% [markdown]
# <a href="https://colab.research.google.com/github/PhucThinh20146028/BTAIW7/blob/main/insurance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
url = '/content/insurance.csv'
data = pd.read_csv(url)
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data.hist()
plt.show()

# %%
correlation = data.corr()
print(correlation)
# Out:
#                age       bmi  children   charges
# age       1.000000  0.109272  0.042469  0.299008
# bmi       0.109272  1.000000  0.012759  0.198341
# children  0.042469  0.012759  1.000000  0.067998
# charges   0.299008  0.198341  0.067998  1.000000

# %%
sns.pairplot(data)

# %%
sns.heatmap(correlation,annot=True)
# Out:
# <Axes: >

# %%
data.plot(kind = 'scatter', x = 'age', y = 'charges', figsize = (9,9), color = 'black')
# Out:
# <Axes: xlabel='age', ylabel='charges'>

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()

model.fit(X = pd.DataFrame(data['age']), y = data['charges'])
print('Gia tri Intercept la: ', model.intercept_)
print('Gia tri Coeffient la: ', model.coef_)
model.score(X = pd.DataFrame(data['age']), y = data['charges'])
# Out:
# Gia tri Intercept la:  3165.885006063021
# Gia tri Coeffient la:  [257.72261867]
# 0.08940589967885804

# %%
data.plot(kind = 'scatter', x = 'age', y = 'charges', figsize = (9,9), color = 'black')
y_pred = model.predict(X = pd.DataFrame(data['age']))
plt.plot(data['age'], y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['age'],data['age']**2]).T

y = data['charges']

model.fit(X,y = data['charges'])
print('He so Intercept la: ', model.intercept_)

print('He so Coeffient la: ', model.coef_)
print('Do chinh xac cua mo hinh la: ', model.score(X,y))
# Out:
# He so Intercept la:  6508.552679699116
# He so Coeffient la:  [64.57305277  2.43890871]
# Do chinh xac cua mo hinh la:  0.09059354818621057

# %%
range = np.arange(19,70,0.1)
X_range = pd.DataFrame([range, range**2]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'age', y = 'charges', figsize = (9,9), color = 'black')
plt.plot(range,y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['age'],data['age']**2,data['age']**3]).T

y = data['charges']

model.fit(X,y = data['charges'])
print('He so Intercept la: ', model.intercept_)
print('He so Coeffient la: ', model.coef_)
print('Do chinh xac cua mo hinh la: ', model.score(X,y))

range = np.arange(19,70,0.1)
X_range = pd.DataFrame([range, range**2, range**3]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'age', y = 'charges', figsize = (9,9), color = 'black')
plt.plot(range,y_pred,color='blue')
# Out:
# He so Intercept la:  600.9022443595968
# He so Coeffient la:  [ 5.86894811e+02 -1.15610409e+01  1.16128288e-01]
# Do chinh xac cua mo hinh la:  0.09097746408882079
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['age'],data['age']**2,data['age']**3,data['age']**4]).T

y = data['charges']

model.fit(X,y = data['charges'])
print('He so Intercept la: ', model.intercept_)
print('He so Coeffient la: ', model.coef_)
print('Do chinh xac cua mo hinh la: ', model.score(X,y))

range = np.arange(19,70,0.1)
X_range = pd.DataFrame([range, range**2, range**3, range**4]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'age', y = 'charges', figsize = (9,9), color = 'black')
plt.plot(range,y_pred,color='blue')
# Out:
# He so Intercept la:  18327.960010364186
# He so Coeffient la:  [-1.51122667e+03  7.54298114e+01 -1.39364486e+00  9.33547640e-03]
# Do chinh xac cua mo hinh la:  0.09131044965439183
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['age'],data['age']**2,data['age']**3,data['age']**4,data['age']**5]).T

y = data['charges']

model.fit(X,y = data['charges'])
print('He so Intercept la: ', model.intercept_)
print('He so Coeffient la: ', model.coef_)
print('Do chinh xac cua mo hinh la: ', model.score(X,y))

range = np.arange(19,70,0.1)
X_range = pd.DataFrame([range, range**2, range**3, range**4, range**5]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'age', y = 'charges', figsize = (9,9), color = 'black')
plt.plot(range,y_pred,color='blue')
# Out:
# He so Intercept la:  -90749.27571055522
# He so Coeffient la:  [ 1.45920797e+04 -8.27348852e+02  2.27222353e+01 -2.99094065e-01
#   1.51819007e-03]
# Do chinh xac cua mo hinh la:  0.09249196059986142
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['age'],data['age']**2,data['age']**3,data['age']**4,data['age']**5,data['age']**6]).T

y = data['charges']

model.fit(X,y = data['charges'])
print('He so Intercept la: ', model.intercept_)
print('He so Coeffient la: ', model.coef_)
print('Do chinh xac cua mo hinh la: ', model.score(X,y))

range = np.arange(19,70,0.1)
X_range = pd.DataFrame([range, range**2, range**3, range**4, range**5, range**6]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'age', y = 'charges', figsize = (9,9), color = 'black')
plt.plot(range,y_pred,color='blue')
# Out:
# He so Intercept la:  -151830.51812583592
# He so Coeffient la:  [ 2.54007523e+04 -1.59183303e+03  5.04388096e+01 -8.43804750e-01
#   7.03673837e-03 -2.25851236e-05]
# Do chinh xac cua mo hinh la:  0.09252734619592873
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['age'],data['age']**2,data['age']**3,data['age']**4,data['age']**5,data['age']**6,data['age']**7]).T

y = data['charges']

model.fit(X,y = data['charges'])
print('He so Intercept la: ', model.intercept_)
print('He so Coeffient la: ', model.coef_)
print('Do chinh xac cua mo hinh la: ', model.score(X,y))

range = np.arange(19,70,0.1)
X_range = pd.DataFrame([range, range**2, range**3, range**4, range**5, range**6, range**7]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'age', y = 'charges', figsize = (9,9), color = 'black')
plt.plot(range,y_pred,color='blue')
# Out:
# He so Intercept la:  37975.51408518919
# He so Coeffient la:  [-1.37851841e+04  1.75716948e+03 -1.03313527e+02  3.25787887e+00
#  -5.66682475e-02  5.11899320e-04 -1.87263959e-06]
# Do chinh xac cua mo hinh la:  0.09256037214359891
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['age'],data['age']**2,data['age']**3,data['age']**4,data['age']**5,data['age']**6,data['age']**7,data['age']**8]).T

y = data['charges']

model.fit(X,y = data['charges'])
print('He so Intercept la: ', model.intercept_)
print('He so Coeffient la: ', model.coef_)
print('Do chinh xac cua mo hinh la: ', model.score(X,y))

range = np.arange(19,70,0.1)
X_range = pd.DataFrame([range, range**2, range**3, range**4, range**5, range**6, range**7, range**8]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'age', y = 'charges', figsize = (9,9), color = 'black')
plt.plot(range,y_pred,color='blue')
# Out:
# He so Intercept la:  7959.725809263982
# He so Coeffient la:  [-2.91903548e+01 -2.92038583e+02  4.74075687e+01 -3.04111942e+00
#   1.00294271e-01 -1.79841855e-03  1.66679323e-05 -6.25407210e-08]
# Do chinh xac cua mo hinh la:  0.09262378874881716
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['age'],data['age']**2,data['age']**3,data['age']**4,data['age']**5,data['age']**6,data['age']**7,data['age']**8,data['age']**9]).T

y = data['charges']

model.fit(X,y = data['charges'])
print('He so Intercept la: ', model.intercept_)
print('He so Coeffient la: ', model.coef_)
print('Do chinh xac cua mo hinh la: ', model.score(X,y))

range = np.arange(19,70,0.1)
X_range = pd.DataFrame([range, range**2, range**3, range**4, range**5, range**6, range**7, range**8, range**9]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'age', y = 'charges', figsize = (9,9), color = 'black')
plt.plot(range,y_pred,color='blue')
# Out:
# He so Intercept la:  3657.7058517099213
# He so Coeffient la:  [-1.19511486e-02 -2.13345136e-01 -1.59902566e+00  5.92261094e-01
#  -4.91165564e-02  1.84026163e-03 -3.55930933e-05  3.46839588e-07
#  -1.34934874e-09]
# Do chinh xac cua mo hinh la:  0.09267345789939208
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['age'],data['age']**2,data['age']**3,data['age']**4,data['age']**5,data['age']**6,data['age']**7,data['age']**8,data['age']**9,data['age']**10]).T

y = data['charges']

model.fit(X,y = data['charges'])
print('He so Intercept la: ', model.intercept_)
print('He so Coeffient la: ', model.coef_)
print('Do chinh xac cua mo hinh la: ', model.score(X,y))

range = np.arange(19,70,0.1)
X_range = pd.DataFrame([range, range**2, range**3, range**4, range**5, range**6, range**7, range**8, range**9, range**10]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'age', y = 'charges', figsize = (9,9), color = 'black')
plt.plot(range,y_pred,color='blue')
# Out:
# He so Intercept la:  4285.077012636684
# He so Coeffient la:  [ 8.51121953e-05  2.98133979e-03  2.74474932e-02  1.94442924e-01
#  -1.39022092e-02  2.44648893e-04  5.53788284e-06 -2.64503170e-07
#   3.53961048e-09 -1.63107830e-11]
# Do chinh xac cua mo hinh la:  0.09268754392926282
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['age'],data['age']**2,data['age']**3,data['age']**4,data['age']**5,data['age']**6,data['age']**7,data['age']**8,data['age']**9,data['age']**10,data['age']**11]).T

y = data['charges']

model.fit(X,y = data['charges'])
print('He so Intercept la: ', model.intercept_)
print('He so Coeffient la: ', model.coef_)
print('Do chinh xac cua mo hinh la: ', model.score(X,y))

range = np.arange(19,70,0.1)
X_range = pd.DataFrame([range, range**2, range**3, range**4, range**5, range**6, range**7, range**8, range**9, range**10,range**11]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'age', y = 'charges', figsize = (9,9), color = 'black')
plt.plot(range,y_pred,color='blue')
# Out:
# He so Intercept la:  5488.6238194002335
# He so Coeffient la:  [ 1.51184481e-07 -1.55414387e-06  1.01803619e-04  1.44248650e-03
#   1.16794591e-02 -1.17105933e-03  4.71656870e-05 -9.47152239e-07
#   9.44347073e-09 -3.73219658e-11 -8.39773875e-17]
# Do chinh xac cua mo hinh la:  0.09307209097207925
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['age'],data['age']**2,data['age']**3,data['age']**4,data['age']**5,data['age']**6,data['age']**7,data['age']**8,data['age']**9,data['age']**10,data['age']**11,data['age']**12]).T

y = data['charges']

model.fit(X,y = data['charges'])
print('He so Intercept la: ', model.intercept_)
print('He so Coeffient la: ', model.coef_)
print('Do chinh xac cua mo hinh la: ', model.score(X,y))

range = np.arange(19,70,0.1)
X_range = pd.DataFrame([range, range**2, range**3, range**4, range**5, range**6, range**7, range**8, range**9, range**10,range**11,range**12]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'age', y = 'charges', figsize = (9,9), color = 'black')
plt.plot(range,y_pred,color='blue')
# Out:
# He so Intercept la:  5720.74961459504
# He so Coeffient la:  [ 1.41884822e-07  1.17696876e-05  1.19646858e-04  1.35094272e-03
#   1.09294164e-02 -1.09723469e-03  4.42363837e-05 -8.88920930e-07
#   8.86667507e-09 -3.50523770e-11 -7.91416764e-17  1.00237879e-16]
# Do chinh xac cua mo hinh la:  0.09410110819718664
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['age'],data['age']**2,data['age']**3,data['age']**4,data['age']**5,data['age']**6,data['age']**7,data['age']**8,data['age']**9,data['age']**10,data['age']**11,data['age']**12,data['age']**13]).T

y = data['charges']

model.fit(X,y = data['charges'])
print('He so Intercept la: ', model.intercept_)
print('He so Coeffient la: ', model.coef_)
print('Do chinh xac cua mo hinh la: ', model.score(X,y))

range = np.arange(19,70,0.1)
X_range = pd.DataFrame([range, range**2, range**3, range**4, range**5, range**6, range**7, range**8, range**9, range**10,range**11,range**12,range**13]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'age', y = 'charges', figsize = (9,9), color = 'black')
plt.plot(range,y_pred,color='blue')
# Out:
# He so Intercept la:  5993.57226259277
# He so Coeffient la:  [ 1.29004844e-07 -6.65291267e-06  1.03998438e-04  1.22213574e-03
#   9.91554881e-03 -9.96779349e-04  4.02306792e-05 -8.08892466e-07
#   8.06937421e-09 -3.18938349e-11 -7.68195356e-17  1.02716297e-16
#   7.96998711e-17]
# Do chinh xac cua mo hinh la:  0.09495662376452352
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['age'],data['age']**2,data['age']**3,data['age']**4,data['age']**5,data['age']**6,data['age']**7,data['age']**8,data['age']**9,data['age']**10,data['age']**11,data['age']**12,data['age']**13,data['age']**14]).T

y = data['charges']

model.fit(X,y = data['charges'])
print('He so Intercept la: ', model.intercept_)
print('He so Coeffient la: ', model.coef_)
print('Do chinh xac cua mo hinh la: ', model.score(X,y))

range = np.arange(19,70,0.1)
X_range = pd.DataFrame([range, range**2, range**3, range**4, range**5, range**6, range**7, range**8, range**9, range**10,range**11,range**12,range**13,range**14]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'age', y = 'charges', figsize = (9,9), color = 'black')
plt.plot(range,y_pred,color='blue')
# Out:
# He so Intercept la:  5759.221107437945
# He so Coeffient la:  [ 1.48332780e-07  1.17270375e-05  6.36829493e-05  1.39674528e-03
#   1.13938697e-02 -1.15355744e-03  4.67920897e-05 -9.44486140e-07
#   9.45280548e-09 -3.74703805e-11 -7.85385889e-17  9.76747573e-17
#   8.81405544e-17 -5.49156871e-17]
# Do chinh xac cua mo hinh la:  0.09534657227978227
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['age'],data['age']**2,data['age']**3,data['age']**4,data['age']**5,data['age']**6,data['age']**7,data['age']**8,data['age']**9,data['age']**10,data['age']**11,data['age']**12,data['age']**13,data['age']**14,data['age']**15]).T

y = data['charges']

model.fit(X,y = data['charges'])
print('He so Intercept la: ', model.intercept_)
print('He so Coeffient la: ', model.coef_)
print('Do chinh xac cua mo hinh la: ', model.score(X,y))

range = np.arange(19,70,0.1)
X_range = pd.DataFrame([range, range**2, range**3, range**4, range**5, range**6, range**7, range**8, range**9, range**10,range**11,range**12,range**13,range**14,range**15]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'age', y = 'charges', figsize = (9,9), color = 'black')
plt.plot(range,y_pred,color='blue')
# Out:
# He so Intercept la:  5753.792875545636
# He so Coeffient la:  [ 1.43649373e-07 -4.28978578e-05  7.93990564e-05  1.44319363e-03
#   1.10357832e-02 -1.11832806e-03  4.54145039e-05 -9.17810291e-07
#   9.19686674e-09 -3.64958629e-11 -9.41239952e-17  9.66921991e-17
#   8.07120755e-17 -4.61819304e-17  4.10048650e-17]
# Do chinh xac cua mo hinh la:  0.09560884589535212
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()

model.fit(X = data.loc[:,['age','bmi']],y = data['charges'])
print('He so coeffient la: ',model.coef_)
print('He so intercept la: ',model.intercept_)
print('Do chinh xac:',model.score(data.loc[:,['age','bmi']],data['charges']))
# Out:
# He so coeffient la:  [241.9307779  332.96509081]
# He so intercept la:  -6424.804612240769
# Do chinh xac: 0.11718338606939938

# %%
model = linear_model.LinearRegression()

model.fit(X = data.loc[:,['age','bmi','children']],y = data['charges'])
print('He so coeffient la: ',model.coef_)
print('He so intercept la: ',model.intercept_)
print('Do chinh xac:',model.score(data.loc[:,['age','bmi','children']],data['charges']))
# Out:
# He so coeffient la:  [239.99447429 332.0833645  542.86465225]
# He so intercept la:  -6916.243347787033
# Do chinh xac: 0.12009819576246927
